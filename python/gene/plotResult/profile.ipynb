# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="white")

# Generate a large random dataset
df_expression = pd.read_csv('/home/syb/Code/coupling/python/file/abagen/expression_210.csv')
df_expression.dropna(inplace=True)
expression_2 = df_expression.values

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(25, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.color_palette("coolwarm", as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(df_expression)
# Out:
# <Axes: >

# %%
df_expression = pd.read_csv('/home/syb/Code/coupling/python/file/abagen/expression_210.csv')
df_expression.dropna(inplace=True)
expression_2 = df_expression.values

# %%
expression_2 = df_expression.values
min1 = np.min(expression_2)
max1 = np.max(expression_2)


plt.imshow(expression_2,aspect='auto',cmap = 'plasma')
plt.show()
