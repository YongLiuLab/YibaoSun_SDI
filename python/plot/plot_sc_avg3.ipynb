# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
sc = np.zeros([3,246,246])

sc[0]  = np.loadtxt('/home/syb/Code/coupling/python/jupyter/file/sc_avg/fa_sc.csv',delimiter=',')
sc[1]  = np.loadtxt('/home/syb/Code/coupling/python/jupyter/file/sc_avg/md_sc.csv',delimiter=',')
sc[2]  = np.loadtxt('/home/syb/Code/coupling/python/jupyter/file/sc_avg/num_sc.csv',delimiter=',')

for i in range(3):
    path_save = '/home/syb/Code/coupling/data/to_local/sc_avg/' + list_save[i] +'_sc.tiff'
    plt.imshow(sc[i],norm = matplotlib.colors.Normalize() )
    plt.axis('off')
    plt.savefig(path_save,bbox_inches='tight', pad_inches = -0.1)
    plt.show()
    list_save = ['fa','md','num']
