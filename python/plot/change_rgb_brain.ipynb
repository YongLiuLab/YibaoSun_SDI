# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pathlib
from matplotlib.pyplot import MultipleLocator

# %%
image = cv2.imread(
    r'F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2\FA_SDI_dif_center1.ni.png'
)  #输入图片路径，如果是在当前工作路径下可以只写xx.jpg


# cv2.imwrite(r'F:\Code\coupling\matlab\file\sub\surface\SDI\fig_out\out.png',
#             image)

fig, ax = plt.subplots(figsize=(15, 20))
x_major_locator = MultipleLocator(50)
# 把x轴的刻度间隔设置为1，并存在变量里
y_major_locator = MultipleLocator(50)
ax.xaxis.set_major_locator(x_major_locator)
# 把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)

plt.setp(ax.get_xticklabels(),size=12,weight='bold',rotation=90)
plt.grid()
plt.imshow(image)

# %%
path = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2')
out_dir = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2_notcolorbar')
#out_dir.mkdir()

for file in path.rglob('*.png'):
    
    image = cv2.imread(str(file))  #输入图片路径，如果是在当前工作路径下可以只写xx.jpg

   
    image[1350:1500, 750:1250, :] = [255, 255, 255]

    temp = image[:, 1030:,:].copy()
    image[:, 1030:,:] = [255, 255, 255]
    num = 50
    image[:, 1030 - num: 2000-num,:] = temp

    temp = image[740:1500, :,:].copy()
    image[740:1500, :,:] = [255, 255, 255]
    num = 40
    image[740-num:1500-num, :,:] = temp

    image = image[50:1350, 50:1900,:].copy()

    out_path = out_dir / file.name
    print(out_path)
    cv2.imwrite(str(out_path), image)
# Out:
# F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2_notcolorbar\FA_SDI_dif_center1.ni.png
# F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2_notcolorbar\FA_SDI_dif_center2.ni.png
# F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2_notcolorbar\FA_SDI_dif_center3.ni.png
# F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2_notcolorbar\FA_SDI_dif_center4.ni.png
# F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2_notcolorbar\FA_SDI_dif_center5.ni.png
# F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2_notcolorbar\FA_SDI_dif_center6.ni.png
# F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2_notcolorbar\FA_SDI_dif_center7.ni.png
# F:\Code\coupling\matlab\file\sub\surface\SDI_dif\centers_T\fig\NC-AD\default2_notcolorbar\MD_SDI_dif_center1.ni.png
# ...

# %%
path = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\SDI_V\fig')
out_dir = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\SDI_V\fig_notcolor')
#out_dir.mkdir()

for file in path.rglob('*.png'):
    print(file)
    image = cv2.imread(str(file))  #输入图片路径，如果是在当前工作路径下可以只写xx.jpg


    image = image[300:1200,150:800]
    out_path = out_dir / file.name

    cv2.imwrite(str(out_path), image)
# Out:
# F:\Code\coupling\matlab\file\sub\surface\SDI_V\fig\Vhigh1.ni.png
# F:\Code\coupling\matlab\file\sub\surface\SDI_V\fig\Vhigh2.ni.png
# F:\Code\coupling\matlab\file\sub\surface\SDI_V\fig\Vlow1.ni.png
# F:\Code\coupling\matlab\file\sub\surface\SDI_V\fig\Vlow2.ni.png

# %%
path = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial')
out_dir = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial_notcolor')
out_dir.mkdir()

for file in path.rglob('*.png'):
    
    image = cv2.imread(str(file))  #输入图片路径，如果是在当前工作路径下可以只写xx.jpg


    image = image[100:1400,450:1400]
    out_path = out_dir / file.name
    print(out_path)
    cv2.imwrite(str(out_path), image)
# Out:
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial\2-28_FA_AD_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial\2-28_FA_MCI_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial\2-28_FA_NC_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial\2-28_MD_AD_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial\2-28_MD_MCI_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial\2-28_MD_NC_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial\2-28_NUM_AD_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial\2-28_NUM_MCI_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_axial\SDI-axial\2-28_NUM_NC_SDI_avg_sub.png

# %%
path = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\corr_bar\fig_4')
out_dir = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\corr_bar\fig_4_notLR_NUM-test')

path = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2')
out_dir = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2-notNUM')
out_dir.mkdir()

for file in path.rglob('*.png'):
    print(file)
    image = cv2.imread(str(file))  #输入图片路径，如果是在当前工作路径下可以只写xx.jpg

    for i in range(1440, 1500):
        for j in range(2000):
            image[i, j, :] = [255, 255, 255]


    out_path = out_dir / file.name

    cv2.imwrite(str(out_path), image)
# Out:
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2\2-28_FA_AD_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2\2-28_FA_MCI_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2\2-28_FA_NC_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2\2-28_MD_AD_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2\2-28_MD_MCI_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2\2-28_MD_NC_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2\2-28_NUM_AD_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2\2-28_NUM_MCI_SDI_avg_sub.png
# F:\Code\coupling\matlab\file\sub\surface\SDI\fig_jet\SDI-material-0.2\2-28_NUM_NC_SDI_avg_sub.png

# %%
path = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\corr_bar\fig_4')
out_dir = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\corr_bar\fig_4_notLR_NUM-test')

path = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\corr_bar\fig_mmse\p_05')
out_dir = pathlib.Path(r'F:\Code\coupling\matlab\file\sub\surface\corr_bar\fig_mmse\p_05_num_down')
out_dir.mkdir()

for file in path.rglob('*.png'):
    print(file)
    image = cv2.imread(str(file))  #输入图片路径，如果是在当前工作路径下可以只写xx.jpg

    for i in range(120):
        for j in range(150):
            image[i, j, :] = [255, 255, 255]

        for j in range(1850,2000):
            image[i, j, :] = [255, 255, 255]

    for i in range(1440, 1500):
        for j in range(2000):
            image[i, j, :] = [255, 255, 255]

    colorbar = image[1350:1450, 750:1250,:].copy()
    a = colorbar[:,250,:]
    

    for i in range(1350, 1450):
        for j in range(750,1250):
            image[i, j, :] = [255, 255, 255]

    image[1400:1500, 750:1250,:]  = colorbar.copy()    

    

    out_path = out_dir / file.name

    cv2.imwrite(str(out_path), image)
# Out:
# F:\Code\coupling\matlab\file\sub\surface\corr_bar\fig_mmse\p_05\FA_MMSE_log_p_05.ni.png
# F:\Code\coupling\matlab\file\sub\surface\corr_bar\fig_mmse\p_05\MD_MMSE_log_p_05.ni.png
# F:\Code\coupling\matlab\file\sub\surface\corr_bar\fig_mmse\p_05\NUM_MMSE_log_p_05.ni.png
